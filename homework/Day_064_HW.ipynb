# %% [markdown]
# # 作業
# * 選擇迴歸資料集(右) - 交錯六群，在其他參數保持預設值的情況下，只允許調整隱藏層層數與神經元數量，且遵守下列限制
# > * 隱藏層神經元總數最多 8 個 (即 : 可以單層 8 個，或兩層 5 個與 3 個)
# > * 遞迴次數只允許跑到500次
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的神經元參數與 Test Loss 數

# %% [markdown]
# # 1HIDDEN LAYER,8 neurons
# Test loss 0.013
# Training loss 0.011
#
# # 2HIDDEN LAYER,4 neurons
# Test loss 0.017
# Training loss 0.016
#
# # 4HIDDEN LAYER,2 neurons
# Test loss 0.033
# Training loss 0.028

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "1X8.PNG"                          #圖片路徑
Image(filename = PATH , width=850, height=600)

# %% [markdown]
# 如何在Jupyter Notebook顯示圖片
# https://medium.com/@yanweiliu/%E5%A6%82%E4%BD%95%E5%9C%A8jupyter-notebook%E9%A1%AF%E7%A4%BA%E5%9C%96%E7%89%87-16e713ae30cd
