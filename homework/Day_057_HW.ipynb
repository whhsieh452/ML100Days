# %% [markdown]
# # 作業
# - 作業目標 : 用 iris (dataset.load_iris()) 資料嘗試跑 hierarchical clustering

# %%
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# 載入 相關套件 並 執行 hierarchical clustering 實驗 ...

# %% [markdown]
# ##import dataset

# %%
from sklearn import datasets
from sklearn import preprocessing
X[:10]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1]])

# %%
from sklearn.cluster import AgglomerativeClustering

# Hierarchical clustering
ward = AgglomerativeClustering(n_clusters=3)
ward_pred = ward.fit_predict(X)

complete = AgglomerativeClustering(n_clusters=3, linkage='complete')
complete_pred = complete.fit_predict(X)

avg = AgglomerativeClustering(n_clusters=3, linkage='average')
avg_pred = avg.fit_predict(X)

# %%
from sklearn.metrics import adjusted_rand_score

ward_ar_score = adjusted_rand_score(y, ward_pred)
complete_ar_score = adjusted_rand_score(y, complete_pred)
avg_ar_score = adjusted_rand_score(y, avg_pred)

print( "Scores: \nWard:", ward_ar_score,"\nComplete: ", complete_ar_score, "\nAverage: ", avg_ar_score)
# Out:
# Scores:
# Ward: 0.7311985567707745
# Complete:  0.64225125183629
# Average:  0.7591987071071522

# %%
from scipy.cluster.hierarchy import linkage
linkage_type = 'average'
linkage_matrix = linkage(X, linkage_type)

# %%
from scipy.cluster.hierarchy import dendrogram
import matplotlib.pyplot as plt
plt.figure(figsize=(25,15))

# plot using 'dendrogram()'
dendrogram(linkage_matrix)
plt.show()

# %%
import seaborn as sns

sns.clustermap(X, figsize=(12,18), method=linkage_type, cmap='viridis')
plt.show()

# %% [markdown]
# ref:
# https://github.com/imehrdadmahdavi/iris-hierarchical-clustering/blob/master/iris-hierarchical-clustering.ipynb
# https://github.com/imehrdadmahdavi/iris-hierarchical-clustering
